# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pygwalker as pyg

# %%
# Load the data
data = pd.read_csv('Coursera_Cleaned_v1.csv')

# %%
data.head()
# Out:
#                                                Title  \
# 0                    Machine Learning Specialization
# 1        Introduction to Data Science Specialization
# 2  Data Science Fundamentals with Python and SQL ...
# 3       Key Technologies for Business Specialization
# 4                       Deep Learning Specialization
#
#                                          Short Intro      Category  \
# 0  #BreakIntoAI with Machine Learning Specializat...  Data Science
# 1  Launch your career in data science. Gain found...  Data Science
# 2  Build the Foundation for your Data Science car...  Data Science
# 3  Get Ahead with Key Business Technologies. Gain...      Business
# 4  Become a Machine Learning expert. Master the f...  Data Science
#
#           Sub-Category     Course Type Language  \
# 0     Machine Learning  Specialization  English
# 1        Data Analysis  Specialization  English
# 2        Data Analysis  Specialization  English
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2819 entries, 0 to 2818
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              2819 non-null   object
#  1   Short Intro        2775 non-null   object
#  2   Category           2819 non-null   object
#  3   Sub-Category       2819 non-null   object
#  4   Course Type        2819 non-null   object
#  5   Language           2819 non-null   object
#  6   Skills             1998 non-null   object
#  7   Instructors        2808 non-null   object
#  8   Rating             2695 non-null   float64
#  9   Number of viewers  1547 non-null   float64
#  10  Duration           2817 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 242.4+ KB

# %%
walker = pyg.walk(data)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0006195a740fb9eaQ1MF6ZaHvCO4XnYu" style="height: auto">\n    <head>…

# %%
# for every categorical
# for every numerical
# show barplot

# Get the categorical columns
categorical_columns = ['Category', 'Sub-Category', 'Course Type', 'Language']

# Get the numerical columns
numerical_columns = ['Rating', 'Number of viewers', 'Duration']

# Nested for loop to iterate over categorical and numerical columns
for categorical_column in categorical_columns:
    # Add count of records barplot
    sns.countplot(x=categorical_column, data=data)
    plt.xticks(rotation=90)  # Rotate x-axis labels vertically
    plt.title(f"Count of courses by {categorical_column}")
    plt.show()
    
    for numerical_column in numerical_columns:
        # Show barplot
        sns.barplot(x=categorical_column, y=numerical_column, data=data)
        plt.xticks(rotation=90)  # Rotate x-axis labels vertically
        plt.title(f"Barplot of {numerical_column} by {categorical_column}")
        plt.show()
        
        # Add sum of views barplot
        if numerical_column == 'Number of viewers':
            sns.barplot(x=categorical_column, y=numerical_column, data=data.dropna(), estimator=sum, ci=None)
            plt.xticks(rotation=90)  # Rotate x-axis labels vertically
            plt.title(f"Sum of {numerical_column} by {categorical_column}")
            plt.show()
# Out:
# /tmp/ipykernel_515/8818483.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=categorical_column, y=numerical_column, data=data.dropna(), estimator=sum, ci=None)
# /home/alessio/anaconda3/lib/python3.11/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /tmp/ipykernel_515/8818483.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=categorical_column, y=numerical_column, data=data.dropna(), estimator=sum, ci=None)
# /home/alessio/anaconda3/lib/python3.11/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /home/alessio/anaconda3/lib/python3.11/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# ...
